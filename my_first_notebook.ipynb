# %% [markdown]
# Hardware refers to the physical components of a computer or device — things you can touch.
#
# Example: A laptop keyboard or mouse.
#
# Software refers to the programs and instructions that run on the hardware — things you cannot physically touch.
#
# Example: Microsoft Word or spotify
